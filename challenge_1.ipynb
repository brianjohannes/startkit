# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/eeg2025/startkit/blob/main/challenge_1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Challenge 1: Cross-Task Transfer Learning!
#
# ## How can we use the knowledge from one EEG Decoding task into another?
#
# Transfer learning is a widespread technique used in deep learning. It uses knowledge learned from one source task/domain in another target task/domain. It has been studied in depth in computer vision, natural language processing, and speech, but what about EEG brain decoding?
#
# The cross-task transfer learning scenario in EEG decoding is remarkably underexplored in comparison to the developers of new models, [Aristimunha et al., (2023)](https://arxiv.org/abs/2308.02408), even though it can be much more useful for real applications, see [Wimpff et al. (2025)](https://arxiv.org/abs/2502.06828), [Wu et al. (2025)](https://arxiv.org/abs/2507.09882).
#
# Our Challenge 1 addresses a key goal in neurotechnology: decoding cognitive function from EEG using the pre-trained knowledge from another. In other words, developing models that can effectively transfer/adapt/adjust/fine-tune knowledge from passive EEG tasks to active tasks.
#
# The ability to generalize and transfer is something critical that we believe should be focused. To go beyond just comparing metrics numbers that are often not comparable, given the specificities of EEG, such as pre-processing, inter-subject variability, and many other unique components of this type of data.
#
# This means your submitted model might be trained on a subset of tasks and fine-tuned on data from another condition, evaluating its capacity to generalize with task-specific fine-tuning.

# %% [markdown]
# __________
#
# Note: For simplicity purposes, we will only show how to do the decoding directly in our target task, and it is up to the teams to think about how to use the passive task to perform the pre-training.

# %% [markdown]
# ---
# ## Summary table for this start kit
#
# In this tutorial, we are going to show in more detail what we want from Challenge 1:
#
# **Contents**:
#
# 0. Understand the Contrast Change Detection - CCD task.
# 1. Understand the [`EEGChallengeDataset`](https://eeglab.org/EEGDash/api/eegdash.html#eegdash.EEGChallengeDataset) object.
# 2. Preparing the dataloaders.
# 3. Building the deep learning model with [`braindecode`](https://braindecode.org/stable/models/models_table.html).
# 4. Designing the training loop.
# 5. Training the model.
# 6. Evaluating test performance.
# 7. Going further, *benchmark go brrr!*
#
#
#
# More contents will be released during the competition inside the [`eegdash`](https://eeglab.org/EEGDash/overview.html) [examples webpage](https://eeglab.org/EEGDash/generated/auto_examples/index.html).
#
# We will establish direct communication channels with you over the next two months, resolve platform issues, and discuss other details.
#
# We are going to do weekly one-hour support time to help teams that may have difficulties with any technical aspects that may arise.
#
# We will have closer communication starting next week, 08/09/2025.
#
# Before we begin, I just want to make a deal with you, ok?
#
# This is a community competition with a strong open-source foundation. When I say open-source, I mean volunteer work.
#
# So, if you see something that does not work or could be improved, first, **please be kind**, and we will fix it together on GitHub, okay?
#
# The entire decoding community will only go further when we stop solving the same problems over and over again, and it starts working together.
#
# ----

# %% [markdown]
# | The tutorial assumes some prior knowledge of deep learning concepts and EEG concepts:|
# | --- |
# |* Standard neural network architectures, e.g., convolutional neural networks|
# |* Optimization by batch gradient descent and backpropagation|
# |* Overfitting, early stopping, regularisation |
# |* Some knowledge of pytorch and, optionally, of the pytorch Lightning framework|
# |* That you know what EEG is |
# |* That you have basic familiarity with EEG preprocessing |
# |* Like and support open-source :) |
#
# **NOTE: You will still be able to run the whole notebook at your own pace and learn about these concepts along the way**
# **NOTE: If you just want run the code and start to play, please go to the challenge version 1, clean in the folder**
#
# ----

# %% [markdown]
# ⚠️ **In case of colab, before starting, make sure you're on a GPU instance for faster training!** ⚠️
#
# > If running on Google Colab, please request a GPU runtime by clicking `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU' under 'Hardware accelerator'.

# %%
# Identify whether a CUDA-enabled GPU is available
import torch

if torch.cuda.is_available():
    device = "cuda"
    msg = "CUDA-enabled GPU found. Training should be faster."
elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = "mps"
    msg = "Apple Silicon GPU (MPS) available. Training will use Metal backend."
else:
    device = "cpu"
    msg = (
        "No GPU found. Training will be carried out on CPU, which might be slower.\n\n"
        "On Mac with Apple Silicon, ensure you have PyTorch >= 1.12 installed with MPS support.\n"
        "See: https://pytorch.org for install instructions."
    )

print(msg)
# Out:
# Apple Silicon GPU (MPS) available. Training will use Metal backend.

# %% [markdown]
# For the challenge, we will need two significant dependencies: `braindecode` and `eegdash`. The libraries will install PyTorch, Pytorch Audio, Scikit-learn, MNE, MNE-BIDS, and many other packages necessary for the many functions.

# %%
#@title ▶️ Install additional required packages for colab
# !pip install braindecode
# !pip install eegdash
# Out:
# Requirement already satisfied: braindecode in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (1.2.0)
# Requirement already satisfied: mne>=1.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (1.10.1)
# Requirement already satisfied: mne_bids>=0.16 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (0.17.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (2.2.6)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (2.3.2)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (1.16.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (3.10.6)
# Requirement already satisfied: h5py in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (3.14.0)
# Requirement already satisfied: skorch>=1.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: einops in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (0.8.1)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (1.5.2)
# Requirement already satisfied: torchinfo~=1.8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (1.8.0)
# Requirement already satisfied: wfdb in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (0.19.1)
# Requirement already satisfied: docstring_inheritance in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode) (2.2.2)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (4.15.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (1.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (2025.9.0)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (5.2.1)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (0.4)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (25.0)
# Requirement already satisfied: pooch>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (1.8.2)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (2.32.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->braindecode) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2025.8.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode) (1.7.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode) (0.9.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from jinja2->torch<3.0,>=2.0->braindecode) (3.0.2)
# Requirement already satisfied: axial-positional-embedding in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.2.3)
# Requirement already satisfied: local-attention in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from local-attention->linear_attention_transformer->braindecode) (0.2.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: aiohttp>=3.10.11 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from wfdb->braindecode) (3.12.15)
# Requirement already satisfied: soundfile>=0.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from wfdb->braindecode) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.20.1)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from soundfile>=0.10.0->wfdb->braindecode) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode) (2.23)
# Requirement already satisfied: eegdash in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (0.3.8)
# Requirement already satisfied: braindecode>=1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (1.2.0)
# Requirement already satisfied: mne_bids>=0.16.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.17.0)
# Requirement already satisfied: numba in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.61.2)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (2.2.6)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (2.3.2)
# Requirement already satisfied: pybids in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.19.0)
# Requirement already satisfied: pymongo in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (4.15.0)
# Requirement already satisfied: python-dotenv in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (1.1.1)
# Requirement already satisfied: s3fs in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (2025.9.0)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (1.16.2)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (4.67.1)
# Requirement already satisfied: xarray in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (2025.9.0)
# Requirement already satisfied: h5io>=0.2.4 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.2.5)
# Requirement already satisfied: pymatreader in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (1.1.0)
# Requirement already satisfied: eeglabio in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.1.0)
# Requirement already satisfied: tabulate in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (0.9.0)
# Requirement already satisfied: docstring_inheritance in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from eegdash) (2.2.2)
# Requirement already satisfied: mne>=1.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.10.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (3.10.6)
# Requirement already satisfied: h5py in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (3.14.0)
# Requirement already satisfied: skorch>=1.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: einops in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (0.8.1)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.5.2)
# Requirement already satisfied: torchinfo~=1.8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.8.0)
# Requirement already satisfied: wfdb in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (0.19.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (4.15.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (2025.9.0)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (5.2.1)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (0.4)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (25.0)
# Requirement already satisfied: pooch>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (1.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.32.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->braindecode>=1.0->eegdash) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2025.8.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode>=1.0->eegdash) (1.7.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode>=1.0->eegdash) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from jinja2->torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.0.2)
# Requirement already satisfied: axial-positional-embedding in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.3)
# Requirement already satisfied: local-attention in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode>=1.0->eegdash) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from local-attention->linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from numba->eegdash) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: nibabel>=4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (5.3.2)
# Requirement already satisfied: formulaic>=0.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (1.2.0)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (2.0.43)
# Requirement already satisfied: bids-validator>=1.14.7 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.10 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (0.5.14)
# Requirement already satisfied: click>=8.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (8.2.1)
# Requirement already satisfied: universal_pathlib>=0.2.2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (0.2.6)
# Requirement already satisfied: frozendict>=2.3 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pybids->eegdash) (2.4.6)
# Requirement already satisfied: bidsschematools>=0.10 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from bids-validator>=1.14.7->pybids->eegdash) (1.1.0)
# Requirement already satisfied: acres in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (0.5.0)
# Requirement already satisfied: pyyaml in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (6.0.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (2.5.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (1.17.3)
# Requirement already satisfied: docopt>=0.6.2 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from num2words>=0.5.10->pybids->eegdash) (0.6.2)
# Requirement already satisfied: xmltodict in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pymatreader->eegdash) (1.0.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from pymongo->eegdash) (2.8.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from s3fs->eegdash) (2.24.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from s3fs->eegdash) (3.12.15)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (0.12.0)
# Requirement already satisfied: botocore<1.40.19,>=1.40.15 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (6.6.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.20.1)
# Requirement already satisfied: soundfile>=0.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from wfdb->braindecode>=1.0->eegdash) (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.23)

# %% [markdown]
# ## 1. What are we decoding?
#
# To start to talk about what we want to analyse, the important thing is to understand some basic concepts.
#
# -----
#
# # The brain decodes the problem
#
# Broadly speaking, here *brain decoding* is the following problem: given brain time-series signals $X \in \mathbb{R}^{C \times T}$ with labels $y \in \mathcal{Y}$, we implement a neural network $f$ that **decodes/translates** brain activity into the target label.
#
# We aim to translate recorded brain activity into its originating stimulus, behavior, or mental state, [King, J-R. et al. (2020)](https://lauragwilliams.github.io/d/m/CognitionAlgorithm.pdf).
#
# The neural network $f$ applies a series of transformation layers (e.g., `torch.nn.Conv2d`, `torch.nn.Linear`, `torch.nn.ELU`, `torch.nn.BatchNorm2d`) to the data to filter, extract features, and learn embeddings relevant to the optimization objective—in other words:
#
# $$
# f_{\theta}: X \to y,
# $$
#
# where $C$ (`n_chans`) is the number of channels/electrodes and $T$ (`n_times`) is the temporal window length/epoch size over the interval of interest. Here, $\theta$ denotes the parameters learned by the neural network.
#
#
# ----
#
# For the competition, the HBN-EEG (Healthy Brain Network EEG Datasets) dataset has `n_chans = 129` with the last channels as [reference channel](https://mne.tools/stable/auto_tutorials/preprocessing/55_setting_eeg_reference.html), and we define the window length as `n_times = 200`, corresponding to 2-second windows.
#
# Your model should follow this definition exactly; any specific selection of channels, filtering, or domain-adaptation technique must be performed **within the layers of the neural network model**.

# %% [markdown]
# If you are interested to get more neuroscience insight, we recommend these two refereces, [HBN-EEG](https://www.biorxiv.org/content/10.1101/2024.10.03.615261v2.full.pdf) and [ Langer, N et al. (2017)](https://www.nature.com/articles/sdata201740#Sec2)
#
# Your task (**label**) is to predict the response time for the subject during this windows.
#
# In the Video, we have an example of recording cognitive activity:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("tOW2Vu2zHoU", start=1630, width=960, height=540)

# %% [markdown]
# In the figure below, we have the timeline representation of the cognitive task:
#
# ![https://eeg2025.github.io/assets/img/CCD_sequence.png](https://eeg2025.github.io/assets/img/image-2.jpg)

# %% [markdown]
# Now, talking about the code, we can start to use `eegdash`!

# %%
from pathlib import Path

DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

from eegdash.dataset import EEGChallengeDataset

dataset_ccd = EEGChallengeDataset(task="contrastChangeDetection",
                                  release="R5", cache_dir=DATA_DIR,
                                  mini=True)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(

# %% [markdown]
# Now, we have a Pytorch Dataset object that contains the set of recordings for the task `contrastChangeDetection`.
#
# This dataset object have very rich Raw object details that can help you to understand better the data. The framework behind this is braindecode, and if you want to understand in depth what is happening, we recommend the braindecode github itself.

# %% [markdown]
# If you want to load the whole release you need change the `mini=False`.

# %%
# For visualization purposes, we will see just one object.

raw = dataset_ccd.datasets[0].raw  # get the Raw object of the first recording
# Out:
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.12B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.03B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.47B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.11B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.23B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.16s/B]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.64B/s]

# %%
fig = raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1169x800 with 4 Axes>

# %% [markdown]
# As you just realized, the eeg dash dataset object will download the dataset only when necessary, and in this case, only when we want to consume the raw data. To download all data directly, we recommend downloading the versions with Amazon API, or doing something like:

# %%
from joblib import Parallel, delayed

raws = Parallel(n_jobs=-1)(
    delayed(lambda d: d.raw)(d) for d in dataset_ccd.datasets
)
# Out:
# Downloading sub-NDARBE091BGD_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.88B/s]]
# Downloading sub-NDARAU708TL8_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAU708TL8_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.62B/s]
#
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
#
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.70B/s]:00<?, ?B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.62B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.69B/s]
#
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
#
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.23B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.02B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.80B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.31B/s]0<?, ?B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.35B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]0<00:00, 3.84B/s]
#
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.84B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.74B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.61B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.57B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.65B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARBE091BGD_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.99B/s]
#
# Downloading sub-NDARBE091BGD_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.63B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.11B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.10B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.09B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.94B/s]
#
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.66B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.66B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.63B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.38s/B]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.21B/s]
# Downloading sub-NDARAU708TL8_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s], ?B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.79B/s]
# Downloading sub-NDARAU708TL8_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDARAU708TL8_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.08B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.99B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.40B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.54B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.53B/s]/s]
#
#
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.58B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.37B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.60B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.48B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.79B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.55B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.72B/s] ?B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:02<00:00, 2.06s/B]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.01B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.97B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.94B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.60B/s]
#
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.78B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.33B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]5.96B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
#
#
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]25B/s]
#
# Downloading sub-NDARBE091BGD_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.02B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.88B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.82B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]?B/s]
# Downloading sub-NDARAU708TL8_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]:00<?, ?B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.23B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARAU708TL8_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
# Downloading sub-NDARAU708TL8_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]0<?, ?B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARBE103DHM_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading sub-NDARBE091BGD_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.78B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.73B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s], ?B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
# Downloading sub-NDARBE103DHM_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]/s]
#
# Downloading sub-NDARBE091BGD_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.12B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAU708TL8_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]0<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAU708TL8_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
#
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARBE091BGD_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s] ?B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.69s/B]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
# Downloading sub-NDARBE091BGD_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARBE091BGD_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]B/s]
# Downloading sub-NDARBE103DHM_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.62B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.67B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.73B/s]B/s]
# Downloading sub-NDARBE103DHM_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
# Downloading sub-NDARBE103DHM_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.69B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARBE103DHM_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARBE103DHM_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.23B/s]
#
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARBE103DHM_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDARBE103DHM_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.70B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s], ?B/s]
# Downloading sub-NDARBE103DHM_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.81B/s]
# Downloading sub-NDARBE103DHM_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.75B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]0:00, 6.52B/s]
#
# Downloading sub-NDARAU708TL8_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]00:00<?, ?B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]0<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
#
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.75B/s]:00<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.00B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARBE103DHM_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.62B/s]
# Downloading sub-NDARAU708TL8_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]0<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]00:00<?, ?B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.29B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARBE091BGD_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARBE103DHM_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAU708TL8_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s] ?B/s]
# Downloading sub-NDARBE103DHM_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]00:00<?, ?B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
#
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARBE091BGD_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.14B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAU708TL8_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.50B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]/s]
# Downloading sub-NDARBE091BGD_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]0<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARBE103DHM_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
# Downloading sub-NDARBE091BGD_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]]
# Downloading sub-NDARAU708TL8_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.70B/s]0<?, ?B/s]
# Downloading sub-NDARBE103DHM_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARBE091BGD_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAU708TL8_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.74B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.70B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]B/s]
# Downloading sub-NDARBE103DHM_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARBE103DHM_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARBE091BGD_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.62B/s]
# Downloading sub-NDARAU708TL8_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.57B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARBE103DHM_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARAU708TL8_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
#
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-3_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s]
# Downloading sub-NDARBE103DHM_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARBE091BGD_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARBE103DHM_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAU708TL8_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]B/s]
# Downloading sub-NDARBE103DHM_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]00<?, ?B/s]
# Downloading sub-NDARBE091BGD_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# ...
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:05<00:00, 5.46s/B]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDARBM433VER_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:14<00:00, 14.1s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.72B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.81B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.56B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.77B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.82B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.67B/s]?, ?B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.84B/s], ?B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.81B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.72B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.79B/s]00:00<?, ?B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]?B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]?B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.69B/s]
# Downloading sub-NDARDV245WJG_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]0<?, ?B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.53B/s] [00:00<?, ?B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.03B/s]
# Downloading sub-NDARDV245WJG_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.15B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]00:00<?, ?B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]0<?, ?B/s]
# Downloading sub-NDARDV245WJG_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.57B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.53B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.13B/s]
# Downloading sub-NDARDV245WJG_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.17B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.04s/B]
# Downloading sub-NDARDV245WJG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.74B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.38B/s]
# Downloading sub-NDARDV245WJG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.22B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.16B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]0, 5.90B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
#
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.63B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.36B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.79B/s]B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.50B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.59B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.65B/s]
# Downloading sub-NDARDV245WJG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.64B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.72B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.61B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.68B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.64B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.60B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.62B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.56B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.45B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.32B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.12B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.50s/B]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.06B/s]?B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.69B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.30B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.87B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.96B/s]:00<?, ?B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:02<00:00, 2.18s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.06B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.54B/s] ?B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.45B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.25B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:02<00:00, 2.73s/B]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.84s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.05B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:05<00:00, 5.24s/B]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:05<00:00, 5.59s/B]
# Downloading sub-NDARCU744XWL_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:08<00:00, 8.88s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.10s/B]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:07<00:00, 7.72s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:02<00:00, 2.35s/B]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:03<00:00, 3.19s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.16B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:03<00:00, 3.38s/B]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:04<00:00, 4.42s/B]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:05<00:00, 5.77s/B]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:18<00:00, 18.9s/B]
# Downloading sub-NDARCU744XWL_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:17<00:00, 17.2s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:11<00:00, 11.2s/B]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:04<00:00, 4.14s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:02<00:00, 2.51s/B]

# %% [markdown]
# ## 2. Creating the windows of interest
#
# Now that we have our raw dataset, defining the windows/epoch interval is essential.
#
# For this challenge, we test many different and semantically different regions of interest, and our preliminary studies show us that the most interesting area of interest is defined below:
#
#
# *        stimulus         │        response         │        feedback
# *                         │ *********************** (stimulus + 0.5)
#
# So we epoch after the stimulus moment with a beginning shift of 500 ms.

# %%
#@title ▶️ Run this first to get all the utils functions for the epoching
from braindecode.datasets import BaseConcatDataset

# %% [markdown]
# So, on our raw data, we fit the events present in it, and create a window of interest.

# %%
from braindecode.preprocessing import preprocess, Preprocessor, create_windows_from_events
from eegdash.hbn.windows import (
    annotate_trials_with_target,
    add_aux_anchors,
    add_extras_columns,
    keep_only_recordings_with,
)

EPOCH_LEN_S = 2.0
SFREQ = 100 # by definition here

transformation_offline = [
    Preprocessor(
        annotate_trials_with_target,
        target_field="rt_from_stimulus", epoch_length=EPOCH_LEN_S,
        require_stimulus=True, require_response=True,
        apply_on_array=False,
    ),
    Preprocessor(add_aux_anchors, apply_on_array=False),
]
preprocess(dataset_ccd, transformation_offline, n_jobs=1)

ANCHOR = "stimulus_anchor"

SHIFT_AFTER_STIM = 0.5
WINDOW_LEN       = 2.0

# Keep only recordings that actually contain stimulus anchors
dataset = keep_only_recordings_with(ANCHOR, dataset_ccd)

# Create single-interval windows (stim-locked, long enough to include the response)
single_windows = create_windows_from_events(
    dataset,
    mapping={ANCHOR: 0},
    trial_start_offset_samples=int(SHIFT_AFTER_STIM * SFREQ),                 # +0.5 s
    trial_stop_offset_samples=int((SHIFT_AFTER_STIM + WINDOW_LEN) * SFREQ),   # +2.5 s
    window_size_samples=int(EPOCH_LEN_S * SFREQ),
    window_stride_samples=SFREQ,
    preload=True,
)

# Injecting metadata into the extra mne annotation.
single_windows = add_extras_columns(
    single_windows,
    dataset,
    desc=ANCHOR,
    keys=("target", "rt_from_stimulus", "rt_from_trialstart",
          "stimulus_onset", "response_onset", "correct", "response_type")
          )
# Out:
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]

# %% [markdown]
# Now that we have our windowed data, we can split it into the different sets that are needed for modeling. Since our challenge focuses on generalization across subjects, we recommend dividing at the subject level.
#
# (1) the training set is used to learn the parameters of our deep learning model,
#
# (2) the validation set is used to monitor the training process and decide when to stop it, and
#
# (3) the test set is used to provide an estimate of the generalization performance of our model.
#
# Here, we use the last 10% of windows for testing, 10% for validation and split the remaining 80% of windows into training.
#
# **Here we go into the steps that you and your team must validate to obtain better results**

# %%
# for each windows, we can extract the metainformation using:

meta_information = single_windows.get_metadata()

# %%
meta_information.head()
# Out:
#    i_window_in_trial  i_start_in_trial  i_stop_in_trial  target  \
# 0                  0             11056            11256    2.11
# 1                  0             11579            11779    1.87
# 2                  0             12259            12459    1.95
# 3                  0             13099            13299     2.1
# 4                  0             13619            13819    1.22
#
#    rt_from_stimulus  rt_from_trialstart  stimulus_onset  response_onset  \
# 0              2.11               4.932         110.062         112.172
# 1              1.87               4.672          115.29          117.16
# 2              1.95                6.35          122.09          124.04
# 3               2.1                 8.1          130.49          132.59
# 4              1.22                4.02          135.69          136.91
#
#    correct      response_type  ... thepresent  diaryofawimpykid  \
# 0        1  right_buttonPress  ...  available         available
# 1        1  right_buttonPress  ...  available         available
# 2        1  right_buttonPress  ...  available         available
# 3        1  right_buttonPress  ...  available         available
# 4        1   left_buttonPress  ...  available         available
#
#   contrastchangedetection_1  contrastchangedetection_2  \
# 0                 available                  available
# 1                 available                  available
# 2                 available                  available
# 3                 available                  available
# 4                 available                  available
#
#   contrastchangedetection_3 surroundsupp_1  surroundsupp_2 seqlearning6target  \
# 0                 available      available       available        unavailable
# 1                 available      available       available        unavailable
# 2                 available      available       available        unavailable
# 3                 available      available       available        unavailable
# 4                 available      available       available        unavailable
#
#   seqlearning8target  symbolsearch
# 0          available     available
# 1          available     available
# 2          available     available
# 3          available     available
# 4          available     available
#
# [5 rows x 36 columns]

# %% [markdown]
# ## You can inspect your target label doing:

# %%
from matplotlib.pylab import plt

fig, ax = plt.subplots(figsize=(15, 5))
ax = meta_information["target"].plot.hist(bins=30, ax=ax, color='lightblue')
ax.set_xlabel("Response Time (s)")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Response Times")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import check_random_state

valid_frac = 0.1
test_frac = 0.1
seed = 2025

subjects = meta_information["subject"].unique()
sub_rm = ["NDARWV769JM7", "NDARME789TD2", "NDARUA442ZVF", "NDARJP304NK1",
          "NDARTY128YLU", "NDARDW550GU6", "NDARLD243KRE", "NDARUJ292JXV", "NDARBA381JGH"]
subjects = [s for s in subjects if s not in sub_rm]

train_subj, valid_test_subject = train_test_split(
    subjects, test_size=(valid_frac + test_frac), random_state=check_random_state(seed), shuffle=True
)

valid_subj, test_subj = train_test_split(
    valid_test_subject, test_size=test_frac, random_state=check_random_state(seed + 1), shuffle=True
)
# sanity check
assert (set(valid_subj) | set(test_subj) | set(train_subj)) == set(subjects)

# %%
# and finally using braindecode split function, we can do:
subject_split = single_windows.split("subject")

train_set = []
valid_set = []
test_set = []

for s in subject_split:
    if s in train_subj:
        train_set.append(subject_split[s])
    elif s in valid_subj:
        valid_set.append(subject_split[s])
    elif s in test_subj:
        test_set.append(subject_split[s])

train_set = BaseConcatDataset(train_set)
valid_set = BaseConcatDataset(valid_set)
test_set = BaseConcatDataset(test_set)

print("Number of examples in each split in the minirelease")
print(f"Train:\t{len(train_set)}")
print(f"Valid:\t{len(valid_set)}")
print(f"Test:\t{len(test_set)}")
# Out:
# Number of examples in each split in the minirelease
# Train:	981
# Valid:	183
# Test:	50

# %% [markdown]
# Finally, we create pytorch `DataLoader`s, which will be used to feed the data to the model during training and evaluation:

# %%
# Create datasets and dataloaders
from torch.utils.data import DataLoader

batch_size = 128
num_workers = 1 # We are using a single worker, but you can increase this for faster data loading

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %% [markdown]
# ## Building the deep learning model
#
# For neural network models, **to start**, we suggest using [braindecode models](https://braindecode.org/1.2/models/models_table.html) zoo. We have implemented several different models for decoding the brain timeseries.
#
# Your team's responsibility is to develop a PyTorch module that receives the three-dimensional (`batch`, `n_chans`, `n_times`) input and outputs the contrastive response time.

# %%
from braindecode.models.util import models_dict

names = sorted(models_dict)
w = max(len(n) for n in names)

for i in range(0, len(names), 3):
    row = names[i:i+3]
    print("  ".join(f"{n:<{w}}" for n in row))
# Out:
# ATCNet                  AttentionBaseNet        AttnSleep
# BDTCN                   BIOT                    CTNet
# ContraWR                Deep4Net                DeepSleepNet
# EEGConformer            EEGITNet                EEGInceptionERP
# EEGInceptionMI          EEGMiner                EEGNeX
# EEGNet                  EEGSimpleConv           EEGTCNet
# FBCNet                  FBLightConvNet          FBMSNet
# IFNet                   Labram                  MSVTNet
# SCCNet                  SPARCNet                ShallowFBCSPNet
# SignalJEPA              SignalJEPA_Contextual   SignalJEPA_PostLocal
# SignalJEPA_PreLocal     SincShallowNet          SleepStagerBlanco2020
# SleepStagerChambon2018  SyncNet                 TIDNet
# TSception               USleep

# %%
# for any braindecode model, you can initialize only inputing the signal related parameters
from braindecode.models import EEGNeX

model = EEGNeX(n_chans=129, # 129 channels
                n_outputs=1, # 1 output for regression
                n_times=200, #2 seconds
                sfreq=100,      # sample frequency 100 Hz
                )

# %%
# the braindecode models have this convenient way to initialize with just the signal parameters
# and also some eegmodulemixin that allow to easily torch info once the model is created

print(model)
# Out:
# ================================================================================================================================================================
# Layer (type (var_name):depth-idx)                            Input Shape               Output Shape              Param #                   Kernel Shape
# ================================================================================================================================================================
# EEGNeX (EEGNeX)                                              [1, 129, 200]             [1, 1]                    --                        --
# ├─Sequential (block_1): 1-1                                  [1, 129, 200]             [1, 8, 129, 200]          --                        --
# │    └─Rearrange (0): 2-1                                    [1, 129, 200]             [1, 1, 129, 200]          --                        --
# │    └─Conv2d (1): 2-2                                       [1, 1, 129, 200]          [1, 8, 129, 200]          512                       [1, 64]
# │    └─BatchNorm2d (2): 2-3                                  [1, 8, 129, 200]          [1, 8, 129, 200]          16                        --
# ├─Sequential (block_2): 1-2                                  [1, 8, 129, 200]          [1, 32, 129, 200]         --                        --
# │    └─Conv2d (0): 2-4                                       [1, 8, 129, 200]          [1, 32, 129, 200]         16,384                    [1, 64]
# │    └─BatchNorm2d (1): 2-5                                  [1, 32, 129, 200]         [1, 32, 129, 200]         64                        --
# ├─Sequential (block_3): 1-3                                  [1, 32, 129, 200]         [1, 64, 1, 50]            --                        --
# │    └─ParametrizedConv2dWithConstraint (0): 2-6             [1, 32, 129, 200]         [1, 64, 1, 200]           --                        [129, 1]
# │    │    └─ModuleDict (parametrizations): 3-1               --                        --                        8,256                     --
# │    └─BatchNorm2d (1): 2-7                                  [1, 64, 1, 200]           [1, 64, 1, 200]           128                       --
# │    └─ELU (2): 2-8                                          [1, 64, 1, 200]           [1, 64, 1, 200]           --                        --
# │    └─AvgPool2d (3): 2-9                                    [1, 64, 1, 200]           [1, 64, 1, 50]            --                        [1, 4]
# │    └─Dropout (4): 2-10                                     [1, 64, 1, 50]            [1, 64, 1, 50]            --                        --
# ├─Sequential (block_4): 1-4                                  [1, 64, 1, 50]            [1, 32, 1, 50]            --                        --
# │    └─Conv2d (0): 2-11                                      [1, 64, 1, 50]            [1, 32, 1, 50]            32,768                    [1, 16]
# │    └─BatchNorm2d (1): 2-12                                 [1, 32, 1, 50]            [1, 32, 1, 50]            64                        --
# ├─Sequential (block_5): 1-5                                  [1, 32, 1, 50]            [1, 48]                   --                        --
# │    └─Conv2d (0): 2-13                                      [1, 32, 1, 50]            [1, 8, 1, 50]             4,096                     [1, 16]
# │    └─BatchNorm2d (1): 2-14                                 [1, 8, 1, 50]             [1, 8, 1, 50]             16                        --
# │    └─ELU (2): 2-15                                         [1, 8, 1, 50]             [1, 8, 1, 50]             --                        --
# │    └─AvgPool2d (3): 2-16                                   [1, 8, 1, 50]             [1, 8, 1, 6]              --                        [1, 8]
# │    └─Dropout (4): 2-17                                     [1, 8, 1, 6]              [1, 8, 1, 6]              --                        --
# │    └─Flatten (5): 2-18                                     [1, 8, 1, 6]              [1, 48]                   --                        --
# ├─ParametrizedLinearWithConstraint (final_layer): 1-6        [1, 48]                   [1, 1]                    1                         --
# │    └─ModuleDict (parametrizations): 2-19                   --                        --                        --                        --
# │    │    └─ParametrizationList (weight): 3-2                --                        [1, 48]                   48                        --
# ================================================================================================================================================================
# Total params: 62,353
# Trainable params: 62,353
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 437.76
# ================================================================================================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 16.65
# Params size (MB): 0.22
# Estimated Total Size (MB): 16.97
# ================================================================================================================================================================
# /opt/homebrew/Caskroom/miniconda/base/envs/eeg2025/lib/python3.13/site-packages/torch/nn/modules/conv.py:543: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1028.)
#   return F.conv2d(

# %% [markdown]
# ### The rest is our classic PyTorch/torch lighting/skorch training pipeline

# %%
# Defining training parameters

lr = 1E-3
weight_decay = 1E-5
n_epochs = 100
early_stopping_patience = 50

# %%
from typing import Optional
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.nn import Module
from torch.optim.lr_scheduler import LRScheduler

def train_one_epoch(
    dataloader: DataLoader,
    model: Module,
    loss_fn,
    optimizer,
    scheduler: Optional[LRScheduler],
    epoch: int,
    device,
    print_batch_stats: bool = True,
):
    # Make sure model is on the correct device and dtype
    if device == "mps":
        model = model.to(device, dtype=torch.float32)
    else:
        model = model.to(device)

    model.train()

    total_loss = 0.0
    sum_sq_err = 0.0
    n_samples = 0

    progress_bar = tqdm(
        enumerate(dataloader), total=len(dataloader), disable=not print_batch_stats
    )

    for batch_idx, batch in progress_bar:
        # Support datasets that may return (X, y) or (X, y, ...)
        X, y = batch[0], batch[1]
        if device == "mps":
            X, y = X.to(device, dtype=torch.float32), y.to(device, dtype=torch.float32)
        else:
            X, y = X.to(device), y.to(device)

        optimizer.zero_grad(set_to_none=True)
        preds = model(X)

        # Keep loss consistent in float32 on MPS
        loss = loss_fn(preds, y)
        if device == "mps":
            loss = loss.to(torch.float32)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Flatten to 1D for regression metrics and accumulate squared error
        preds_flat = preds.detach().view(-1)
        y_flat = y.detach().view(-1)
        sum_sq_err += torch.sum((preds_flat - y_flat) ** 2).item()
        n_samples += y_flat.numel()

        if print_batch_stats:
            running_rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
            progress_bar.set_description(
                f"Epoch {epoch}, Batch {batch_idx + 1}/{len(dataloader)}, "
                f"Loss: {loss.item():.6f}, RMSE: {running_rmse:.6f}"
            )

    if scheduler is not None:
        scheduler.step()

    avg_loss = total_loss / len(dataloader)
    rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
    return avg_loss, rmse

# %%
import torch
from torch.utils.data import DataLoader
from torch.nn import Module
from tqdm import tqdm

@torch.no_grad()
def valid_model(
    dataloader: DataLoader,
    model: Module,
    loss_fn,
    device,
    print_batch_stats: bool = True,
):
    model.eval()

    # Make sure model weights are float32 if running on MPS
    if device == "mps":
        model = model.to(torch.float32)

    total_loss = 0.0
    sum_sq_err = 0.0
    n_batches = len(dataloader)
    n_samples = 0

    iterator = tqdm(
        enumerate(dataloader),
        total=n_batches,
        disable=not print_batch_stats
    )

    for batch_idx, batch in iterator:
        # Supports (X, y) or (X, y, ...)
        X, y = batch[0], batch[1]
        X, y = X.to(device, dtype=torch.float32), y.to(device, dtype=torch.float32)

        preds = model(X)

        # Ensure loss_fn also works in float32
        batch_loss = loss_fn(preds, y).float().item()
        total_loss += batch_loss

        preds_flat = preds.detach().view(-1)
        y_flat = y.detach().view(-1)
        sum_sq_err += torch.sum((preds_flat - y_flat) ** 2).item()
        n_samples += y_flat.numel()

        if print_batch_stats:
            running_rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
            iterator.set_description(
                f"Val Batch {batch_idx + 1}/{n_batches}, "
                f"Loss: {batch_loss:.6f}, RMSE: {running_rmse:.6f}"
            )

    avg_loss = total_loss / n_batches if n_batches else float("nan")
    rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5

    print(f"Val RMSE: {rmse:.6f}, Val Loss: {avg_loss:.6f}\n")
    return avg_loss, rmse

# %%
import copy

optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=n_epochs - 1)
loss_fn = torch.nn.MSELoss()

patience = 5
min_delta = 1e-4
best_rmse = float("inf")
epochs_no_improve = 0
best_state, best_epoch = None, None

for epoch in range(1, n_epochs + 1):
    print(f"Epoch {epoch}/{n_epochs}: ", end="")

    train_loss, train_rmse = train_one_epoch(
        train_loader, model, loss_fn, optimizer, scheduler, epoch, device
    )
    val_loss, val_rmse = valid_model(test_loader, model, loss_fn, device)

    print(
        f"Train RMSE: {train_rmse:.6f}, "
        f"Average Train Loss: {train_loss:.6f}, "
        f"Val RMSE: {val_rmse:.6f}, "
        f"Average Val Loss: {val_loss:.6f}"
    )

    if val_rmse < best_rmse - min_delta:
        best_rmse = val_rmse
        best_state = copy.deepcopy(model.state_dict())
        best_epoch = epoch
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch}. Best Val RMSE: {best_rmse:.6f} (epoch {best_epoch})")
            break

if best_state is not None:
    model.load_state_dict(best_state)
# Out:
# Epoch 1/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 1, Batch 8/8, Loss: 2.390936, RMSE: 1.504723: 100%|██████████| 8/8 [00:14<00:00,  1.77s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 2.285649, RMSE: 1.511836: 100%|██████████| 1/1 [00:07<00:00,  7.33s/it]
# Val RMSE: 1.511836, Val Loss: 2.285649
#
# Train RMSE: 1.504723, Average Train Loss: 2.269512, Val RMSE: 1.511836, Average Val Loss: 2.285649
# Epoch 2/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 2, Batch 8/8, Loss: 2.167060, RMSE: 1.435926: 100%|██████████| 8/8 [00:10<00:00,  1.30s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 2.036102, RMSE: 1.426921: 100%|██████████| 1/1 [00:07<00:00,  7.20s/it]
# Val RMSE: 1.426921, Val Loss: 2.036102
#
# Train RMSE: 1.435926, Average Train Loss: 2.066301, Val RMSE: 1.426921, Average Val Loss: 2.036102
# Epoch 3/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 3, Batch 8/8, Loss: 1.657706, RMSE: 1.327434: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 1.891125, RMSE: 1.375182: 100%|██████████| 1/1 [00:07<00:00,  7.23s/it]
# Val RMSE: 1.375182, Val Loss: 1.891125
#
# Train RMSE: 1.327434, Average Train Loss: 1.757697, Val RMSE: 1.375182, Average Val Loss: 1.891125
# Epoch 4/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 4, Batch 8/8, Loss: 0.824329, RMSE: 1.215283: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 1.691324, RMSE: 1.300509: 100%|██████████| 1/1 [00:07<00:00,  7.25s/it]
# Val RMSE: 1.300509, Val Loss: 1.691324
#
# Train RMSE: 1.215283, Average Train Loss: 1.449510, Val RMSE: 1.300509, Average Val Loss: 1.691324
# Epoch 5/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 5, Batch 8/8, Loss: 0.477335, RMSE: 1.046560: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 2.821782, RMSE: 1.679816: 100%|██████████| 1/1 [00:07<00:00,  7.26s/it]
# Val RMSE: 1.679816, Val Loss: 2.821782
#
# Train RMSE: 1.046560, Average Train Loss: 1.069339, Val RMSE: 1.679816, Average Val Loss: 2.821782
# Epoch 6/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 6, Batch 8/8, Loss: 0.308510, RMSE: 0.914638: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 3.101942, RMSE: 1.761233: 100%|██████████| 1/1 [00:07<00:00,  7.25s/it]
# Val RMSE: 1.761233, Val Loss: 3.101942
#
# Train RMSE: 0.914638, Average Train Loss: 0.814388, Val RMSE: 1.761233, Average Val Loss: 3.101942
# Epoch 7/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 7, Batch 8/8, Loss: 0.310753, RMSE: 0.743536: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 4.877011, RMSE: 2.208396: 100%|██████████| 1/1 [00:07<00:00,  7.27s/it]
# Val RMSE: 2.208396, Val Loss: 4.877011
#
# Train RMSE: 0.743536, Average Train Loss: 0.542680, Val RMSE: 2.208396, Average Val Loss: 4.877011
# Epoch 8/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 8, Batch 8/8, Loss: 0.238016, RMSE: 0.651623: 100%|██████████| 8/8 [00:10<00:00,  1.30s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 5.207782, RMSE: 2.282057: 100%|██████████| 1/1 [00:07<00:00,  7.28s/it]
# Val RMSE: 2.282057, Val Loss: 5.207782
#
# Train RMSE: 0.651623, Average Train Loss: 0.416777, Val RMSE: 2.282057, Average Val Loss: 5.207782
# Epoch 9/100:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Epoch 9, Batch 8/8, Loss: 0.243146, RMSE: 0.601478: 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Val Batch 1/1, Loss: 5.087806, RMSE: 2.255617: 100%|██████████| 1/1 [00:07<00:00,  7.24s/it]
# Val RMSE: 2.255617, Val Loss: 5.087806
#
# Train RMSE: 0.601478, Average Train Loss: 0.356794, Val RMSE: 2.255617, Average Val Loss: 5.087806
# Early stopping at epoch 9. Best Val RMSE: 1.300509 (epoch 4)

# %%
# saving the model

torch.save(model.state_dict(), "model.pth")

# %% [markdown]
# # Common questions:

# %% [markdown]
# 1) Do I need to use only braindecode?
#
# No! You can use any model that gets a tensor as input, outputs a tensor, and implements the forward method.
#
# 2) Can I apply extra preprocessing/dataset loader for the hidden data?
#
# No, any transformation needs to be inside your model. but we are super open to contributions to the libraries (eggdash and braindecode) to accommodate any reasonable request.
